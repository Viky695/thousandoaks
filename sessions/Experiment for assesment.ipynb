# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %% [markdown]
# ### we use pandas.read_csv() function to access the file "gapminder.tsv" stored in a remote location
#
# ### the remote location is: https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/
#
# ### with the argument sep='\t' we indicate that the columns are separated by tabs rather than commas.
#
# df = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminder= df

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
type(gapminder)
# Out:
# pandas.core.frame.DataFrame

# %%
gapminder.shape
# Out:
# (1704, 6)

# %%
gapminder.info
# Out:
# <bound method DataFrame.info of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]>

# %%
gapminder.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
gapminder['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df[['country', 'pop']]
# Out:
#           country       pop
# 0     Afghanistan   8425333
# 1     Afghanistan   9240934
# 2     Afghanistan  10267083
# 3     Afghanistan  11537966
# 4     Afghanistan  13079460
# ...           ...       ...
# 1699     Zimbabwe   9216418
# 1700     Zimbabwe  10704340
# 1701     Zimbabwe  11404948
# 1702     Zimbabwe  11926563
# 1703     Zimbabwe  12311143
#
# [1704 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
df.groupby('country')['lifeExp'].mean()
# Out:
# country
# Afghanistan                 37.478833
# Albania                     68.432917
# Algeria                     59.030167
# Angola                      37.883500
# Argentina                   69.060417
# Australia                   74.662917
# Austria                     73.103250
# Bahrain                     65.605667
# Bangladesh                  49.834083
# Belgium                     73.641750
# Benin                       48.779917
# Bolivia                     52.504583
# Bosnia and Herzegovina      67.707833
# Botswana                    54.597500
# Brazil                      62.239500
# Bulgaria                    69.743750
# Burkina Faso                44.694000
# Burundi                     44.817333
# Cambodia                    47.902750
# Cameroon                    48.128500
# Canada                      74.902750
# Central African Republic    43.866917
# Chad                        46.773583
# Chile                       67.430917
# ...

# %%
df.groupby(['country','year'])['lifeExp'].mean()
# Out:
# country                   year
# Afghanistan               1952    28.80100
#                           1957    30.33200
#                           1962    31.99700
#                           1967    34.02000
#                           1972    36.08800
#                           1977    38.43800
#                           1982    39.85400
#                           1987    40.82200
#                           1992    41.67400
#                           1997    41.76300
#                           2002    42.12900
#                           2007    43.82800
# Albania                   1952    55.23000
#                           1957    59.28000
#                           1962    64.82000
#                           1967    66.22000
#                           1972    67.69000
#                           1977    68.93000
#                           1982    70.42000
#                           1987    72.00000
#                           1992    71.58100
# ...

# %%
df.groupby(['continent','year'])['pop'].max()
# Out:
# continent  year
# Africa     1952      33119096
#            1957      37173340
#            1962      41871351
#            1967      47287752
#            1972      53740085
#            1977      62209173
#            1982      73039376
#            1987      81551520
#            1992      93364244
#            1997     106207839
#            2002     119901274
#            2007     135031164
# Americas   1952     157553000
#            1957     171984000
#            1962     186538000
#            1967     198712000
#            1972     209896000
#            1977     220239000
#            1982     232187835
#            1987     242803533
#            1992     256894189
#            1997     272911760
#            2002     287675526
#            2007     301139947
# Asia       1952     556263527
#            1957     637408000
#            1962     665770000
#            1967     754550000
#            1972     862030000
#            1977     943455000
# ...

# %%
df.groupby(['continent','year'])['gdpPercap'].max()
# Out:
# continent  year
# Africa     1952      4725.295531
#            1957      5487.104219
#            1962      6757.030816
#            1967     18772.751690
#            1972     21011.497210
#            1977     21951.211760
#            1982     17364.275380
#            1987     11864.408440
#            1992     13522.157520
#            1997     14722.841880
#            2002     12521.713920
#            2007     13206.484520
# Americas   1952     13990.482080
#            1957     14847.127120
#            1962     16173.145860
#            1967     19530.365570
#            1972     21806.035940
#            1977     24072.632130
#            1982     25009.559140
#            1987     29884.350410
#            1992     32003.932240
#            1997     35767.433030
#            2002     39097.099550
#            2007     42951.653090
# Asia       1952    108382.352900
#            1957    113523.132900
#            1962     95458.111760
#            1967     80894.883260
# ...

# %%
df.groupby('year')['lifeExp'].mean().round(2)
# Out:
# year
# 1952    49.06
# 1957    51.51
# 1962    53.61
# 1967    55.68
# 1972    57.65
# 1977    59.57
# 1982    61.53
# 1987    63.21
# 1992    64.16
# 1997    65.01
# 2002    65.69
# 2007    67.01
# Name: lifeExp, dtype: float64

# %%
pd.set_option('display.max_rows', None)

# %%
df[["year", "lifeExp"]].groupby("year").mean().round(2)
# Out:
#       lifeExp
# year
# 1952    49.06
# 1957    51.51
# 1962    53.61
# 1967    55.68
# 1972    57.65
# 1977    59.57
# 1982    61.53
# 1987    63.21
# 1992    64.16
# 1997    65.01
# 2002    65.69
# 2007    67.01

# %%
df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
df[["continent","year", "lifeExp", "gdpPercap"]].groupby(["year","continent"]).mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
Plottingtheresults=df.groupby('year')['lifeExp'].mean()

# %%
Plot2= df[["year", "lifeExp"]].groupby("year").mean().round(2)

# %%
Plottingtheresults
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
Plot2
# Out:
#       lifeExp
# year
# 1952    49.06
# 1957    51.51
# 1962    53.61
# 1967    55.68
# 1972    57.65
# 1977    59.57
# 1982    61.53
# 1987    63.21
# 1992    64.16
# 1997    65.01
# 2002    65.69
# 2007    67.01

# %%
Plot2.plot()

# %%
Plottingtheresults.plot()

# %%
Check= df.groupby(['continent','year'])['lifeExp'].mean()

# %%
Check.unstack(level=0).plot(kind='line', subplots=False,figsize=(10,10))

# %%
Check2= df[["continent", "year", "lifeExp"]].groupby(["continent", "year"]).mean()

# %%
Check2.unstack(level=0).plot(kind='line', subplots=False,figsize=(10,10))

# %%
Check2
# Out:
#                   lifeExp
# continent year
# Africa    1952  39.135500
#           1957  41.266346
#           1962  43.319442
#           1967  45.334538
#           1972  47.450942
#           1977  49.580423
#           1982  51.592865
#           1987  53.344788
#           1992  53.629577
#           1997  53.598269
#           2002  53.325231
#           2007  54.806038
# Americas  1952  53.279840
#           1957  55.960280
#           1962  58.398760
#           1967  60.410920
#           1972  62.394920
#           1977  64.391560
#           1982  66.228840
#           1987  68.090720
#           1992  69.568360
#           1997  71.150480
#           2002  72.422040
#           2007  73.608120
# Asia      1952  46.314394
#           1957  49.318544
#           1962  51.563223
#           1967  54.663640
#           1972  57.319269
#           1977  59.610556
#           1982  62.617939
#           1987  64.851182
#           1992  66.537212
#           1997  68.020515
# ...

# %%
pd.set_option('display.min_rows', None)

# %%
Check2.head(36)
# Out:
#                   lifeExp
# continent year
# Africa    1952  39.135500
#           1957  41.266346
#           1962  43.319442
#           1967  45.334538
#           1972  47.450942
#           1977  49.580423
#           1982  51.592865
#           1987  53.344788
#           1992  53.629577
#           1997  53.598269
#           2002  53.325231
#           2007  54.806038
# Americas  1952  53.279840
#           1957  55.960280
#           1962  58.398760
#           1967  60.410920
#           1972  62.394920
#           1977  64.391560
#           1982  66.228840
#           1987  68.090720
#           1992  69.568360
#           1997  71.150480
#           2002  72.422040
#           2007  73.608120
# Asia      1952  46.314394
#           1957  49.318544
#           1962  51.563223
#           1967  54.663640
#           1972  57.319269
#           1977  59.610556
#           1982  62.617939
#           1987  64.851182
#           1992  66.537212
#           1997  68.020515
# ...

# %%
# filter to select country as India 

CountryFilter=df['country']=='India'

# %%
gapminder[CountryFilter]
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 696   India      Asia  1952   37.373   372000000   546.565749
# 697   India      Asia  1957   40.249   409000000   590.061996
# 698   India      Asia  1962   43.605   454000000   658.347151
# 699   India      Asia  1967   47.193   506000000   700.770611
# 700   India      Asia  1972   50.651   567000000   724.032527
# 701   India      Asia  1977   54.208   634000000   813.337323
# 702   India      Asia  1982   56.596   708000000   855.723538
# 703   India      Asia  1987   58.553   788000000   976.512676
# 704   India      Asia  1992   60.223   872000000  1164.406809
# 705   India      Asia  1997   61.765   959000000  1458.817442
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
filtertofindlifeExp= (df['lifeExp']<= 40)&(df['pop']>50000000)

# %%
df[filtertofindlifeExp]
# Out:
#         country continent  year  lifeExp        pop   gdpPercap
# 97   Bangladesh      Asia  1957   39.348   51365468  661.637458
# 696       India      Asia  1952   37.373  372000000  546.565749
# 708   Indonesia      Asia  1952   37.468   82052000  749.681655
# 709   Indonesia      Asia  1957   39.918   90124000  858.900271

# %%
# Slicing the rows 1-12 from the main Data Frame
df.iloc[1:12]
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 1   Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415  635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923  974.580338

# %%
# Slicing including columns
df.iloc[1:12,0:5]
# Out:
#         country continent  year  lifeExp       pop
# 1   Afghanistan      Asia  1957   30.332   9240934
# 2   Afghanistan      Asia  1962   31.997  10267083
# 3   Afghanistan      Asia  1967   34.020  11537966
# 4   Afghanistan      Asia  1972   36.088  13079460
# 5   Afghanistan      Asia  1977   38.438  14880372
# 6   Afghanistan      Asia  1982   39.854  12881816
# 7   Afghanistan      Asia  1987   40.822  13867957
# 8   Afghanistan      Asia  1992   41.674  16317921
# 9   Afghanistan      Asia  1997   41.763  22227415
# 10  Afghanistan      Asia  2002   42.129  25268405
# 11  Afghanistan      Asia  2007   43.828  31889923

# %%
Chinafilter=df[df['country']=='China']

# %%
Chinafilter
# Out:
#     country continent  year   lifeExp         pop    gdpPercap
# 288   China      Asia  1952  44.00000   556263527   400.448611
# 289   China      Asia  1957  50.54896   637408000   575.987001
# 290   China      Asia  1962  44.50136   665770000   487.674018
# 291   China      Asia  1967  58.38112   754550000   612.705693
# 292   China      Asia  1972  63.11888   862030000   676.900092
# 293   China      Asia  1977  63.96736   943455000   741.237470
# 294   China      Asia  1982  65.52500  1000281000   962.421380
# 295   China      Asia  1987  67.27400  1084035000  1378.904018
# 296   China      Asia  1992  68.69000  1164970000  1655.784158
# 297   China      Asia  1997  70.42600  1230075000  2289.234136
# 298   China      Asia  2002  72.02800  1280400000  3119.280896
# 299   China      Asia  2007  72.96100  1318683096  4959.114854

# %%
Graph=Chinafilter[['lifeExp']]

# %%
Graph
# Out:
#       lifeExp
# 288  44.00000
# 289  50.54896
# 290  44.50136
# 291  58.38112
# 292  63.11888
# 293  63.96736
# 294  65.52500
# 295  67.27400
# 296  68.69000
# 297  70.42600
# 298  72.02800
# 299  72.96100

# %%
Graph.plot()

# %%
Chinafilter.plot(x= 'year', y= 'lifeExp')

# %% [markdown]
# ### Which countries have gdpPerCap larger than 30000 dollars ?

# %%
GDP3000= (df['gdpPercap']<3000)

# %%
df[GDP3000]
# Out:
#                        country continent  year   lifeExp         pop  \
# 0                  Afghanistan      Asia  1952  28.80100     8425333
# 1                  Afghanistan      Asia  1957  30.33200     9240934
# 2                  Afghanistan      Asia  1962  31.99700    10267083
# 3                  Afghanistan      Asia  1967  34.02000    11537966
# 4                  Afghanistan      Asia  1972  36.08800    13079460
# 5                  Afghanistan      Asia  1977  38.43800    14880372
# 6                  Afghanistan      Asia  1982  39.85400    12881816
# 7                  Afghanistan      Asia  1987  40.82200    13867957
# 8                  Afghanistan      Asia  1992  41.67400    16317921
# 9                  Afghanistan      Asia  1997  41.76300    22227415
# 10                 Afghanistan      Asia  2002  42.12900    25268405
# 11                 Afghanistan      Asia  2007  43.82800    31889923
# 12                     Albania    Europe  1952  55.23000     1282697
# ...
